# %% [markdown]
# 前面两行引入相应的库，真正的代码就4行，够简单吧。第1行甚至可以不写，它定义了图的大小。第2行我们创建一个地图，第3行把海岸线画上，第4行显示这个地图，就是这样

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

plt.figure(figsize=(16,8))
m = Basemap()
m.drawcoastlines()

plt.show()

# %% [markdown]
# 然后我们开始画上国家

# %% [markdown]
# 如果我们想显示中国地图，只需要在创建Basemap时指定一下经纬度就行了
# 然后就得到了中国地图

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

plt.figure(figsize=(16,8))
m = Basemap()
m.drawcountries(linewidth=1.5)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=73, llcrnrlat=18, urcrnrlon=135, urcrnrlat=53)
m.drawcountries(linewidth=1.5)
plt.show()

# %% [markdown]
# 看上去有点变形，这是因为我们没有添加任何投影的原因，Basemap提供24种不同的投影方式，你可以自己一个个试一下，比较常用的是兰勃特投影，我们添加一下：

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.drawcountries(linewidth=1.5)
plt.show()

# %% [markdown]
# 这次终于看上去比较正常了
# 我们想加上省的边界怎么办呢？Basemap缺省的包里没有中国的省区，只有美国的州，毕竟是美国人做的嘛。不过好在世界很大，有专门的国际组织干这事，在这里你可以下载全世界任何一个国家的行政区划Shape文件，然后我们给它加上

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.readshapefile('CHN_adm_shp/CHN_adm1', 'states', drawbounds=True)
m.drawcountries(linewidth=1.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-625bd834f1eb> in <module>()
#       4 plt.figure(figsize=(16,8))
#       5 m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
# ----> 6 m.readshapefile('CHN_adm_shp/CHN_adm1', 'states', drawbounds=True)
#       7 m.drawcountries(linewidth=1.5)
#       8 plt.show()
#
# /usr/local/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2114         shp.default_encoding = default_encoding
#    2115         if not os.path.exists('%s.shp'%shapefile):
# -> 2116             raise IOError('cannot locate %s.shp'%shapefile)
#    2117         if not os.path.exists('%s.shx'%shapefile):
#    2118             raise IOError('cannot locate %s.shx'%shapefile)
#
# OSError: cannot locate CHN_adm_shp/CHN_adm1.shp

# %% [markdown]
# 再往后，你还可以往图上改颜色啦，写数字啦，这些就留待你研究吧。总之，我想说的是，用Python画地图真的超容易。
